# %% [markdown]
# # Data Science and Business Analytics Internship

# %% [markdown]
# # Graduate Rotational Internship Program(GRIP) August 2021

# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# # Task 3: Exploratory Data Analysis- Retail

# %% [markdown]
# # Objective: To perform Exploratory Data Analysis on dataset 'SampleSuperstore'

# %% [markdown]
# # Author: Kirti Dass

# %% [markdown]
# ## 1. Importing all the required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 2. Reading the dataset

# %%
retail=pd.read_csv("D:/SampleSuperstore.csv")
retail
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ## 3. Describing the dataset

# %%
retail.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
retail.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
retail.shape
# Out:
# (9994, 13)

# %%
retail.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
retail.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
retail.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
retail['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
retail['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
retail['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
retail['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
retail['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %% [markdown]
# ## 4. Cleaning the dataset

# %%
retail.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
retdata=retail.drop(['Country','Postal Code'],axis=1)

# %%
retdata.head()
# Out:
#         Ship Mode    Segment             City       State Region  \
# 0    Second Class   Consumer        Henderson    Kentucky  South
# 1    Second Class   Consumer        Henderson    Kentucky  South
# 2    Second Class  Corporate      Los Angeles  California   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# ## 5. Heatmap and Correlation

# %%
corelation=retdata.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### From the above heatmap we infer:
# ### (i) Sales and Profit have a mild positive correlation
# ### (ii) Discount and Profit are negatively related, albeit very weakly

# %%
sns.pairplot(retdata,hue='Ship Mode')

# %%
sns.pairplot(retdata,hue='Segment')

# %%
sns.pairplot(retdata,hue='Category')

# %%
sns.pairplot(retdata,hue='Region')

# %% [markdown]
# ### The above pairplots across various domains re-establish the mild positive relation between sales and profit.

# %% [markdown]
# ## 6. Distribution of Sales, Quantity, Profit and Discount

# %%
retdata[['Sales','Discount','Profit']].plot.box(vert = False, grid = True)
# Out:
# <AxesSubplot:>

# %%
retdata[['Quantity']].plot.hist(bins = 5, title = 'Purchase Quantity')
# Out:
# <AxesSubplot:title={'center':'Purchase Quantity'}, ylabel='Frequency'>

# %%
retdata[['Sales']].plot.hist(bins = 20, title = 'Sales')
# Out:
# <AxesSubplot:title={'center':'Sales'}, ylabel='Frequency'>

# %%
retdata.plot.scatter(x = 'Sales', y = 'Profit',
                  color = 'brown', title = 'Sales Vs Profit')
# Out:
# <AxesSubplot:title={'center':'Sales Vs Profit'}, xlabel='Sales', ylabel='Profit'>

# %%
sns.kdeplot(data=retdata, x="Sales", hue="Region")
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(retdata['Sales'],color='green',label='Sales',shade=True)
sns.kdeplot(retdata['Profit'],color='brown',label='Profit',shade=True)
plt.xlim([-100,1000])
plt.legend()

# %% [markdown]
# ### Both Sales and Profit distribution are skewed to the right, with Sales distribution lying entirely above that of Profit towards higher data points.

# %% [markdown]
# ## 7. Analysis of Categorical Variables Using Countplots

# %%
ax = sns.countplot(x="Region", data=retdata)
plt.title('Region',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Region')

# %% [markdown]
# ### The Western region receives the highest number of orders, while South has the the lowest number of deals/orders.

# %%
ax = sns.countplot(x="Category", data=retdata)
plt.title('Category',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Category')

# %% [markdown]
# ### Maximum number of orders are from the category of Office Supplies. The orders/deals from the other two categories of Furniture and Technology are approximately less than half of that of Office Supplies.

# %%
plt.figure(figsize=(20,8))
ax = sns.countplot(x="Sub-Category", data=retdata)
plt.title('Sub-Category',fontsize=20)
plt.tight_layout()

# %% [markdown]
# ### Binders are the most ordered sub-category, while Copiers have the least number of orders.

# %%
ax = sns.countplot(x="Ship Mode", data=retdata)
plt.title('Ship Mode',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Ship Mode')

# %% [markdown]
# ### Standard Class is the ship mode used for maximum number of orders. Very few orders are have a shipping demand of Same Day.

# %%
ax = sns.countplot(x="Segment", data=retdata)
plt.title('Segment',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Segment')

# %% [markdown]
# ### The highest number of orders belong to the segment of Consumers. Home Office has the least number of orders.

# %% [markdown]
# ## 8. Sales and Profit Analysis Across States

# %%
plt.figure(figsize=(5,20))
ax=sns.barplot(x="Sales",y="State",data=retdata,ci=None)
plt.title("Sales Across States",fontsize=14)
# Out:
# Text(0.5, 1.0, 'Sales Across States')

# %%
retdata1=retdata['State'].value_counts()

# %%
retdata1.plot(kind='bar',figsize=(15,5))
plt.ylabel('Frequency / Number of deals')
plt.xlabel('States')

plt.title('State Wise Dealings', fontsize = 20)
plt.show()

# %% [markdown]
# ### Wyoming has the highest amount of sales, but the lowest number of deals or orders. It can be inferred that the order from Wyoming could be from a category with a high price. The states of California, New York and Texas have the highest number of orders. However, these states have a low sales amount on average implying either orders from categories with a low price or orders in small quantities.

# %%
retdata_sort=retdata.sort_values("Profit")
plt.figure(figsize=(8,20))
ax=sns.barplot(x="Profit",y="State",data=retdata_sort,ci=None)
plt.title("Profit Across States",fontsize=15)
plt.tight_layout()

# %% [markdown]
# ### Most Profitable States
# #### 1. Vermont
# #### 2. Rhode Island
# #### 3. Indiana
# #### 4. Montana
# #### 5. Minnesota
#
# ### States with Maximum losses
# #### 1. Ohio
# #### 2. Colorado
# #### 3. North Carolina
# #### 4. Tennessee
# #### 5. Pennsylvania

# %% [markdown]
# ## <font color='green'> (a) Sales of Loss Incurring States</font>

# %%
ax=sns.barplot(x="State",y="Sales",data=retdata,ci=None,order=["North Carolina","Ohio","Tennessee","Colorado","Pennsylvania"])
plt.title("Sales of Loss Incurring States",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Sales of Loss Incurring States')

# %% [markdown]
# ### North Carolina has the highest amount of sales among the top 5 loss making states.

# %% [markdown]
# ## <font color='green'> (b) Profit of States with High Number of Orders and Large Sales</font>

# %%
plt.figure(figsize=(9,4))
ax=sns.barplot(x="State",y="Profit",data=retdata,ci=None,order=["California","New York","Texas","Pennsylvania","Washington","Wyoming","Vermont","Nevada"])
plt.title("Profit of States with High Number of Orders and Large Sales",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Profit of States with High Number of Orders and Large Sales')

# %% [markdown]
# ### Texas and Pennsylvania are incurring losses, despite having large number of orders.

# %% [markdown]
# ## <font color='green'> (c) Category Wise Profit Analysis of States with Large Sales</font>

# %%
ax=sns.barplot(x="State",y="Profit",hue="Category",data=retdata,ci=None,order=["Wyoming","Vermont","Nevada"])
plt.title("Category Wise Profit Analysis of States with Large Sales",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Category Wise Profit Analysis of States with Large Sales')

# %% [markdown]
# ### Wyoming receives orders only in the Furniture category and reports profits. Vermont makes the highest profit in the category of Furniture. Nevada's profit shares are approximately equal across all categories.

# %% [markdown]
# ## <font color='green'> (d)  Cross-Categorical Profit Analysis of States with Large Sales (Segment and Category)</font>

# %%
g=sns.catplot(x="State",y="Profit",hue="Segment",col="Category",data=retdata,kind="bar",ci=None,height=4,aspect=0.8,order=["Wyoming","Vermont","Nevada"])

# %% [markdown]
# ### Vermont makes the highest profit in the furniture category across the corporate segment. Nevada records the highest profit in the office supllies category across the home office segment. All the three states with the largest sales record profit.

# %% [markdown]
# ## <font color='green'> (e) Cross-Categorical Profit Analysis of States with Large Sales (Ship Mode and Category)</font>

# %%
g=sns.catplot(x="State",y="Profit",hue="Ship Mode",col="Category",data=retdata,kind="bar",ci=None,height=5,aspect=0.99,order=["Wyoming","Vermont","Nevada"])

# %% [markdown]
# ### Vermont makes the highest profit in the standard class shipping mode for furniture category. Nevada incurs a small loss in the standard class ship mode in the furniture category.

# %% [markdown]
# ## <font color='green'> (f) Category Wise Profit Analysis of States with High Orders</font>

# %%
ax=sns.barplot(x="State",y="Profit",hue="Category",data=retdata,ci=None,order=["California","New York","Texas","Pennsylvania","Washington"])

# %% [markdown]
# ### Pennsylvania incurs losses across all the categories. Texas reports profits only in the Technology category. The other threee states report profits across all categories, with New York recording the highest profit in the Technology category.

# %% [markdown]
# ## <font color='green'> (g) Cross-Categorical Profit Analysis of States with High Orders (Segment and Category)</font>

# %%
g=sns.catplot(x="State",y="Profit",hue="Segment",col="Category",kind="bar",data=retdata,ci=None,order=["California","New York","Texas","Pennsylvania","Washington"])

# %% [markdown]
# ### Texas reports profits in the technology category across all segments. Pennsylvania makes a small profit in the consumer segment in the Technology category, however this miniscule profit is wiped out by haevy losses in the other two segments.

# %% [markdown]
# ## <font color='green'>(h) Cross-Categorical Profit Analysis of States with High Orders (Ship Mode and Category)</font>

# %%
g=sns.catplot(x="State",y="Profit",hue="Ship Mode",col="Category",kind="bar",data=retdata,ci=None,order=["California","New York","Texas","Pennsylvania","Washington"])

# %% [markdown]
# ### New York reports small losses in the same day shipping mode in the furniture category. All the states except Pennsylvania have considerable profits across all ship modes in the technology category. Again, Texas makes small profits across all ship modes in the Technology category. Washington has the highest profits in the First Class ship mode in thr Technology category.

# %% [markdown]
# ## <font color=green>(i) Category Wise Sales Analysis of Most Profitable States<font/>

# %%
ax=sns.barplot(x="State",y="Sales",hue="Category",data=retdata,ci=None,order=["Vermont","Rhode Island","Indiana","Montana","Minnesota"])

# %% [markdown]
# ### The most profitable state Vermont has the largest sales in the category of furniture. All the states record significant sales in the technology category.

# %% [markdown]
# ## <font color='green'>(j) Cross-Categorical Sales Analysis of Most Profitable States (Segment and Category)<font/>

# %%
g=sns.catplot(x="State",y="Sales",hue="Segment",col="Category",kind="bar",data=retdata,ci=None,order=["Vermont","Rhode Island","Indiana","Montana","Minnesota"])

# %% [markdown]
# ### All the states record high sales in the corporate and home office segment across all categories. Technology category items are mostly in the home office segment in all these states.

# %% [markdown]
# ## <font color='green'>(k) Cross-Categorical Sales Analysis of Most Profitable States (Ship Mode and Category)<font/>

# %%
g=sns.catplot(x="State",y="Sales",hue="Ship Mode",col="Category",kind="bar",data=retdata,ci=None,order=["Vermont","Rhode Island","Indiana","Montana","Minnesota"])

# %% [markdown]
# ### Standard Class ship mode has the highest sales across these profitable states.

# %% [markdown]
# ## <font color=green>(l) Category Wise Sales Analysis of Most Loss-Incurring States<font/>

# %%
ax=sns.barplot(x="State",y="Sales",hue="Category",data=retdata,ci=None,order=["North Carolina","Ohio","Tennessee","Colorado","Pennsylvania"])

# %% [markdown]
# ### Technology category has the highest sales across all the loss-making states. Furniture has the second highest sales.

# %% [markdown]
# ## <font color='green'>(m) Cross-Categorical Sales Analysis of Most Loss-Incurring States (Segment and Category)<font/>

# %%
g=sns.catplot(x="State",y="Sales",hue="Segment",col="Category",kind="bar",data=retdata,ci=None,order=["North Carolina","Ohio","Tennessee","Colorado","Pennsylvania"])

# %% [markdown]
# ### North Carolina has the largest sales in the corporate segment of the technology category.

# %% [markdown]
# ## <font color='green'>(n) Cross-Categorical Sales Analysis of Most Lost-Incurring States (Ship Mode and Category)<font/>

# %%
g=sns.catplot(x="State",y="Sales",hue="Ship Mode",col="Category",kind="bar",data=retdata,ci=None,order=["North Carolina","Ohio","Tennessee","Colorado","Pennsylvania"])

# %% [markdown]
# ### All the loss making states report a large amount of sales through the same day ship mode across all the categories, with North Carolina having the highest in the Technology Category.

# %% [markdown]
# ## 9. Sales and Profit Analysis Across Cities

# %%
retdata2=retdata['City'].value_counts()
retdata2=retdata2.head(30)

# %%
retdata2.plot(kind='bar',figsize=(15,5))
plt.ylabel('Number of Sales')
plt.xlabel('City')

plt.title('City-wise Sales of top 30 cities',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(5,100))
ax=sns.barplot(x="Sales",y="City",data=retdata,ci=None)
plt.title("Sales Across Cities",fontsize=18)
# Out:
# Text(0.5, 1.0, 'Sales Across Cities')

# %% [markdown]
# ### Cities with the largest amount of Sales:
# ### Jamestown, Cheyenne, Burbank, Lehi, Lafayette, Burlington, Independence, Minneapolis
# ### Cities with the largest number of orders:
# ### New York City, Los Angeles, Philadelphia, San Francisco, Seattle

# %%
plt.figure(figsize=(5,100))
ax=sns.barplot(x="Profit",y="City",data=retdata_sort,ci=None)
plt.title("Profit Across Cities",fontsize=18)
# Out:
# Text(0.5, 1.0, 'Profit Across Cities')

# %% [markdown]
# ### Cities with the largest profits: Jamestown,Independence,Lafayette,Minneapolis,Morristown,Lehi,Warwick
# ### Cities with the largest Losses: Bethlehem,Oswego,Round Rock,Champaign,Clarksville,Lancaster

# %% [markdown]
# ## <font color='green'>(a) Sales of Most Profitable Cities<font/>

# %%
ax=sns.barplot(x="Sales",y="City",data=retdata,ci=None,order=["Jamestown","Independence","Lafayette","Minneapolis","Morristown","Lehi","Warwick"])
plt.title("Sales of Most Profitable Cities",fontsize=14)
# Out:
# Text(0.5, 1.0, 'Sales of Most Profitable Cities')

# %% [markdown]
# ### Jamestown has the largest amount of sales amongnst the most profitable cities.

# %% [markdown]
# ## <font color='green'>(b) Category Wise Sales Analysis of Most Profitable Cities<font/>

# %%
ax=sns.barplot(x="Sales",y="City",hue="Category",data=retdata,ci=None,order=["Jamestown","Independence","Lafayette","Minneapolis","Morristown","Lehi","Warwick"])

# %% [markdown]
# ### Technology as a category has the largest amount of sales across all these profit making cities.

# %% [markdown]
# ## <font color='green'>(c) Cross-Categorical Sales Analysis of Most Profitable Cities (Segment and Category)<font/>

# %%
g=sns.catplot(x="Sales",y="City",hue="Segment",col="Category",data=retdata,kind="bar",ci=None,order=["Jamestown","Independence","Lafayette","Minneapolis","Morristown","Lehi","Warwick"])

# %% [markdown]
# ## <font color='green'>(d) Cross-Categorical Sales Analysis of Most Profitable Cities (Ship Mode and Category)<font/>

# %%
g=sns.catplot(x="Sales",y="City",hue="Ship Mode",col="Category",data=retdata,kind="bar",ci=None,order=["Jamestown","Independence","Lafayette","Minneapolis","Morristown","Lehi","Warwick"])

# %% [markdown]
# ## <font color='green'>(e) Sales of Most Loss-Incurring Cities<font/>

# %%
ax=sns.barplot(x="Sales",y="City",data=retdata,ci=None,order=["Bethlehem","Oswego","Round Rock","Champaign","Clarksville","Lancaster"])

# %% [markdown]
# ### Round Rock has the highest sales amongst the top loss incurring cities.

# %% [markdown]
# ## <font color='green'>(f) Category Wise Sales Analysis of Most Loss-Incurring Cities<font/>

# %%
ax=sns.barplot(x="Sales",y="City",hue="Category",data=retdata,ci=None,order=["Bethlehem","Oswego","Round Rock","Champaign","Clarksville","Lancaster"])

# %% [markdown]
# ### Office Supplies have considerable sales across all these loss incurring cities. This is followed by technology.

# %% [markdown]
# ## <font color='green'>(g) Cross-Categorical Sales Analysis of Most Loss-Incurring Cities (Segment and Category)<font/>

# %%
g=sns.catplot(x="Sales",y="City",hue="Segment",col="Category",data=retdata,kind="bar",ci=None,order=["Bethlehem","Oswego","Round Rock","Champaign","Clarksville","Lancaster"])

# %% [markdown]
# ### Office supplies category mostly has orders in the Consumer degment across all these loss making cities.

# %% [markdown]
# ## <font color='green'>(h) Cross-Categorical Sales Analysis of Most Loss-Incurring Cities (Ship Mode and Category)<font/>

# %%
g=sns.catplot(x="Sales",y="City",hue="Ship Mode",col="Category",data=retdata,kind="bar",ci=None,order=["Bethlehem","Oswego","Round Rock","Champaign","Clarksville","Lancaster"])

# %% [markdown]
# ## <font color='green'>(i) Profit of Cities With Largest Sales<font/>

# %%
ax=sns.barplot(x="Profit",y="City",data=retdata,ci=None,order=["Jamestown","Cheyenne","Burbank","Lehi","Lafayette","Burlington","Independence","Minneapolis"])
plt.title("Profit of Cities with Largest Sales",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Profit of Cities with Largest Sales')

# %% [markdown]
# ### Burlington is the city with high sales which incurs losses.

# %% [markdown]
# ## <font color='green'>(j) Category Wise Profit Analysis of Cities With Largest Sales<font/>

# %%
g=sns.catplot(x="Profit",y="City",hue="Category",data=retdata,ci=None,kind="bar",order=["Jamestown","Cheyenne","Burbank","Lehi","Lafayette","Burlington","Independence","Minneapolis"])

# %% [markdown]
# ### Lafayette records the highest profit  in the technology category. Burlington reports losses both in the Office Supplies and the Technology Category.

# %% [markdown]
# ## <font color='green'>(k) Profit of Cities With Highest Orders<font/>

# %%
ax=sns.barplot(x="Profit",y="City",data=retdata,ci=None,order=["New York City","Los Angeles","Philadelphia","San Francisco","Seattle"])

# %% [markdown]
# ### Philadelphia records losses amongst the cities with highest orders. The other cities report overall profit.

# %% [markdown]
# ## <font color='green'>(l) Categorical Profit Analysis of  Cities With Highest Orders<font/>

# %%
ax=sns.barplot(x="Profit",y="City",hue="Category",data=retdata,ci=None,order=["New York City","Los Angeles","Philadelphia","San Francisco","Seattle"])

# %% [markdown]
# ### Philadelphia incurs losses across all categories, the highest being in the Furniture category. All the other cities report considerable profits in the Technology Category.

# %% [markdown]
# ## 10. Region Wise Analysis

# %%
retdata_region=retdata.groupby(['Region'])[['Sales','Profit','Discount']].mean()
retdata_region
# Out:
#               Sales     Profit  Discount
# Region
# Central  215.772661  17.092709  0.240353
# East     238.336110  32.135808  0.145365
# South    241.803645  28.857673  0.147253
# West     226.493233  33.849032  0.109335

# %%
ax=sns.barplot(x="Sales",y="Region",data=retdata,ci=None)
plt.title("Region Wise Sales",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Region Wise Sales')

# %%
ax=sns.catplot(x="Sales",y="Region",data=retdata)
plt.title("Region Wise Sales",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Region Wise Sales')

# %%
ax=sns.barplot(x="Profit",y="Region",data=retdata,ci=None)
plt.title("Region Wise Profit",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Region Wise Profit')

# %%
ax=sns.catplot(x="Profit",y="Region",data=retdata)
plt.title("Region Wise Profit",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Region Wise Profit')

# %%
ax=sns.barplot(x="Discount",y="Region",data=retdata,ci=None)
plt.title("Region Wise Dicount",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Region Wise Dicount')

# %%
ax=sns.catplot(x="Discount",y="Region",data=retdata)
plt.title("Region Wise Discount",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Region Wise Discount')

# %% [markdown]
# ### East and South have the largest amount of Sales, whereas West records the highest profits. Central offers the highest discount among all the regions.

# %% [markdown]
# ## <font color=green>(a) Sales Analysis of Regions across Category and Ship Mode<font/>

# %%
g=sns.catplot(x="Ship Mode",y="Sales",hue="Category",col="Region",data=retdata,ci=None,kind="bar",height=5,aspect=0.99)

# %% [markdown]
# ### Technology is the category clocking-in the highest amount of sales across all four regions. Office Supplies have the lowest amount of sales.

# %% [markdown]
# ## <font color=green>(b) Profit Analysis of Regions across Category and Ship Mode<font/>

# %%
g=sns.catplot(x="Ship Mode",y="Profit",hue="Category",col="Region",data=retdata,ci=None,kind="bar",height=5,aspect=0.99)

# %% [markdown]
# ### All the four regions record considerable profits across all the regions and ship modes except for same day shipping in South. Central incurs losses in the furniture category across all ship modes. Office Supplies bring in small profits in all the regions across all shipping modes.

# %% [markdown]
# ## <font color=green>(c) Sales Analysis of Regions across Category and Segment<font/>

# %%
g=sns.catplot(x="Segment",y="Sales",hue="Category",col="Region",data=retdata,ci=None,kind="bar",height=5,aspect=0.99)

# %% [markdown]
# ### Technology has largest amount of sales roughly across all the segments.

# %% [markdown]
# ## <font color=green>(d) Profit Analysis of Regions across Category and Segment<font/>

# %%
g=sns.catplot(x="Segment",y="Profit",hue="Category",col="Region",data=retdata,ci=None,kind="bar",height=5,aspect=0.99)

# %% [markdown]
# ### Central reports losses in the consumer and home office segments of furniture category. Technology brings in the largest profits across all the segments and categories in all the regions. Furniture brings in very small profits across all segments in the Eastern region.

# %% [markdown]
# ## 11. Category-Wise Analysis

# %%
retdata_category=retdata.groupby(['Category'])[['Sales','Profit','Discount']].mean()
retdata_category
# Out:
#                       Sales     Profit  Discount
# Category
# Furniture        349.834887   8.699327  0.173923
# Office Supplies  119.324101  20.327050  0.157285
# Technology       452.709276  78.752002  0.132323

# %%
ax=sns.barplot(x="Sales",y="Category",data=retdata,ci=None)
plt.title("Category Wise Sales",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Category Wise Sales')

# %%
g=sns.catplot(x="Sales",y="Category",data=retdata)
plt.title("Category Wise Sales",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Category Wise Sales')

# %% [markdown]
# ### Technology has the highest amount of sales among all the categories.

# %% [markdown]
# ## <font color=green>(a) Sales Analysis of Category across Ship Mode and Segment<font/>

# %%
g=sns.catplot(x="Segment",y="Sales",hue="Ship Mode",col="Category",kind="bar",data=retdata,ci=None)

# %% [markdown]
# ### Same Day shipments have the largest amount of sale in the corporate segment of technology category. Sales in the Office Supplies category is considerably low across all the ship modes compared to other categories.

# %%
ax=sns.barplot(x="Profit",y="Category",data=retdata,ci=None)
plt.title("Category Wise Profit",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Category Wise Profit')

# %% [markdown]
# ### Technology is the category with the highest amount of profits,whereas furniture has the least amount of profit.

# %% [markdown]
# ## <font color=green>(b) Profit Analysis of Category across Ship Mode and Segment<font/>

# %%
g=sns.catplot(x="Segment",y="Profit",hue="Ship Mode",col="Category",kind="bar",data=retdata,ci=None)

# %% [markdown]
# ### First Class ship mode in the home office category of technology records the highest profit.

# %% [markdown]
# ## <font color=green>(c) Discount Analysis across Category<font/>

# %%
ax=sns.barplot(x="Discount",y="Category",data=retdata,ci=None)
ax=sns.catplot(x="Discount",y="Category",data=retdata)

# %% [markdown]
# ### Furniture offers the highest discount among all categories, whereas technology offers the least discount.

# %% [markdown]
# ## 12. Ship Mode-Wise Analysis

# %%
ax=sns.barplot(x="Sales",y="Ship Mode",data=retdata,ci=None)
plt.title("Ship Mode Wise Sales",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Ship Mode Wise Sales')

# %%
ax=sns.catplot(x="Sales",y="Ship Mode",data=retdata)
plt.title("Ship Mode Wise Sales",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Ship Mode Wise Sales')

# %% [markdown]
# ### Second class and same day shipments roughly have the same amount of sales.

# %% [markdown]
# ## <font color=green>(a) Sales Analysis of Ship Mode across Segment and Category<font/>

# %%
g=sns.catplot(x="Segment",y="Sales",hue="Category",col="Ship Mode",kind="bar",data=retdata,ci=None)

# %% [markdown]
# ### Same day shipments in the corportae segment of the technolgy category have the highest amount of sales

# %%
ax=sns.barplot(x="Profit",y="Ship Mode",data=retdata,ci=None)
plt.title("Ship Mode Wise Profit",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Ship Mode Wise Profit')

# %%
ax=sns.catplot(x="Profit",y="Ship Mode",data=retdata)
plt.title("Ship Mode Wise Profit",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Ship Mode Wise Profit')

# %% [markdown]
# ### First Class shipping mode is the most profitable.

# %% [markdown]
# ## <font color=green>(b) Profit Analysis of Ship Mode across Segment and Category<font/>

# %%
g=sns.catplot(x="Segment",y="Profit",hue="Category",col="Ship Mode",kind="bar",data=retdata,ci=None)

# %% [markdown]
# ### Home Office segment in the technology category using first class shipment is the most profitable.

# %% [markdown]
# ## <font color=green>(c) Discount Analysis of Ship Mode<font/>

# %%
ax=sns.barplot(x="Discount",y="Ship Mode",data=retdata,ci=None)
plt.title("Ship Mode Wise Discount",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Ship Mode Wise Discount')

# %%
ax=sns.catplot(x="Discount",y="Ship Mode",data=retdata)
plt.title("Ship Mode Wise Discount",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Ship Mode Wise Discount')

# %% [markdown]
# ## 13. Segment-Wise Analysis

# %%
ax=sns.barplot(x="Sales",y="Segment",data=retdata,ci=None)
plt.title("Segment Wise Sales",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Segment Wise Sales')

# %%
ax=sns.catplot(x="Sales",y="Segment",data=retdata)
plt.title("Segment Wise Sales",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Segment Wise Sales')

# %% [markdown]
# ### Home Office Segment has the largest amount of sales.

# %% [markdown]
# ## <font color=green>(a) Sales Analysis of Segment across Ship Mode and Category<font/>

# %%
g=sns.catplot(x="Category",y="Sales",hue="Ship Mode",col="Segment",kind="bar",data=retdata,ci=None)

# %%
ax=sns.barplot(x="Profit",y="Segment",data=retdata,ci=None)
plt.title("Segment Wise Profit",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Segment Wise Profit')

# %%
ax=sns.catplot(x="Profit",y="Segment",data=retdata)
plt.title("Segment Wise Profit",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Segment Wise Profit')

# %% [markdown]
# ### Home Office segment is the most profitable.

# %% [markdown]
# ## <font color=green>(b) Profit Analysis of Segment across Ship Mode and Category<font/>

# %%
g=sns.catplot(x="Category",y="Sales",hue="Ship Mode",col="Segment",kind="bar",data=retdata,ci=None)

# %% [markdown]
# ## <font color=green>(c) Discount Analysis of Segment<font/>

# %%
ax=sns.barplot(x="Discount",y="Segment",data=retdata,ci=None)
plt.title("Segment Wise Discount",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Segment Wise Discount')

# %%
ax=sns.catplot(x="Discount",y="Segment",data=retdata)
plt.title("Segment Wise Discount",fontsize=16)
# Out:
# Text(0.5, 1.0, 'Segment Wise Discount')

# %% [markdown]
# ### Consumer offers the highest discount across all the segments.

# %% [markdown]
# ## 14. Sub-Category Wise Analysis

# %% [markdown]
# ## <font color=green>(a) Sales Analysis of Sub-Category across Segment and Category<font/>

# %%
g=sns.catplot(x="Category",y="Sales",hue="Segment",col="Sub-Category",data=retdata,kind="bar",col_wrap=4,ci=None,height=3,aspect=0.99)

# %% [markdown]
# ### Tables have the highest amount of sales in the furniture category. Appliances and Supplies have the kargest amount of sales in the Office Supplies category whereas Copiers have the highest sales in the technology category.

# %% [markdown]
# ## <font color=green>(a) Profit Analysis of Sub-Category across Segment and Category<font/>

# %%
g=sns.catplot(x="Category",y="Profit",hue="Segment",col="Sub-Category",data=retdata,kind="bar",col_wrap=4,ci=None,height=3,aspect=0.99)

# %% [markdown]
# ### Bookcases in the consumer segment report losses. Copiers record high profits.

# %% [markdown]
# ## <font color=red>Problems and Weak Areas-Summary<font/>

# %% [markdown]
# ### 1. Ohio is the state with maximum losses. This could be probabaly due to (i) high sales in furniture category- category with the least profits (ii) high sales in consumer and corporate segments.
# ### 2. Bethelem is the city with the highest losses. The city records high sales in the consumer segment of Office Supplies which could be the possible reason behind its losses.
# ### 3. Furniture is the least profitable category, and also the one with the maximum discounts.
# ### 4. Standard Shipping have the lowest profits, whereas second day shipping modes are highly profitable.
# ### 5. Consumer segment is the least profitable of all the segments.
# ### 6. Bookcases and Binders have the lowest profit among the sub-categories.
# ### 7. Technology category in corporate segment with same day shipping has both high sales and high profits- a possible area of expansion in the loss making cities and states.
